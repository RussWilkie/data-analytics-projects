# %%
#API keys file
import config

from googleapiclient.discovery import build
import pandas as pd
from IPython.display import JSON
from dateutil import parser
import isodate

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
nltk.download('punkt')
from wordcloud import WordCloud
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.

# %%
api_key =

# %%
channel_ids = ['UCMsP14U4Pp4tcm52ryt14zA']

# %%
api_service_name = "youtube"
api_version = "v3"

youtube = build(api_service_name, api_version, developerKey=api_key)
def get_channel_stats(youtube, channel_ids):
    all_data = []
    
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics",
        id=','.join(channel_ids)
    )
    response = request.execute()

    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscribers': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'paylistId':item['contentDetails']['relatedPlaylists']['uploads']
               }
        
        all_data.append(data)
    return(pd.DataFrame(all_data))

# %%
channel_stats = get_channel_stats(youtube, channel_ids)

# %%
channel_stats
# Out:
#            channelName subscribers  views totalVideos  \
# 0  Midwest Bow & Arrow         587  23046           9
#
#                   paylistId
# 0  UUMsP14U4Pp4tcm52ryt14zA

# %%
playlist_id = 'UUMsP14U4Pp4tcm52ryt14zA'

def get_video_ids(youtube, playlist_id):
    video_ids = []
    
    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId="UUMsP14U4Pp4tcm52ryt14zA",
        maxResults = 50
    )
    response = request.execute()

    for item in response['items']:
        video_ids.append(item['contentDetails']['videoId'])

    next_page_token=response.get('nextPageToken')
    while(next_page_token is not None):
        request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId="UUMsP14U4Pp4tcm52ryt14zA",
        maxResults = 50,
        pageToken = next_page_token
    )
        response = request.execute()
    
        for item in response['items']:
            video_ids.append(item['contentDetails']['videoId'])
        next_page_token=response.get('nextPageToken')
    
    return video_ids

# %%
video_ids = get_video_ids(youtube,playlist_id)

# %%
len(video_ids)
# Out:
# 9

# %%
def get_video_details(youtube, video_ids):
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %%
video_df = get_video_details(youtube, video_ids)
video_df
# Out:
#       video_id         channelTitle  \
# 0  TuIJMMTlUqU  Midwest Bow & Arrow
# 1  CwDmKZ85B14  Midwest Bow & Arrow
# 2  YaWiiPFDL4A  Midwest Bow & Arrow
# 3  vMgFeG9YSHU  Midwest Bow & Arrow
# 4  8yapCQvNerg  Midwest Bow & Arrow
# 5  f27RBDQ-qII  Midwest Bow & Arrow
# 6  Ynvrepob1QA  Midwest Bow & Arrow
# 7  JsGGLmrDol4  Midwest Bow & Arrow
# 8  jjECrxjVLEw  Midwest Bow & Arrow
#
#                                                title  \
# 0                  80# Hoyt Ventum Pro 33 Speed Test
# 1  Hoyt Z1S vs PSE Omen vs 80# Ventum Pro 33 - SP...
# 2  Create Your One Stick: The Wingman Platform by...
# 3  Iron Will Broadheads - Solid vs Vented Noise Test
# 4  Iron Will Broadheads - How LOUD are the vented...
# 5         The Sound of Archery - South Forty Archers
# 6  Mathews UltraRest Integrated MX (QAD) - Slow M...
# 7  Hoyt REDWRX Carbon RX-1 Ultra - Nockturnal Lig...
# 8     Hoyt Defiant 34 - Red Nockturnal Lighted Nocks
#
#                                          description  \
# 0  check out https://www.bwanaarchery.com/\ngo fo...
# 1  Bwana Archery\nShoot off between the speed bow...
# 2  Part 2/2 will show you how to use it. \n\nLink...
# 3  Pure unscientific broadhead noise testing betw...
# 4  Pure unscientific broadhead noise testing betw...
# 5                      would you just listen to that
# 6  Mathews VXR 31.5\nMathews UltraRest Integrated...
# 7  Hoyt REDWRX Carbon RX-1 Ultra - Nockturnal Lig...
# 8  Nockturnal Lighted Nocks are awesome! \nHoyt D...
#
#                                                 tags           publishedAt  \
# 0  [HOYT Z1S, HOYT VENTUM PRO, 80LB BOW, 80# BOW,...  2023-01-09T14:50:12Z
# 1  [HOYT Z1S, HOYT VENTUM PRO, 80LB BOW, 80# BOW,...  2022-12-29T14:45:00Z
# 2  [archery country, powder ridge 3d shoot, pse e...  2022-08-17T13:44:45Z
# 3  [IRON WILL ARCHERY, iron will broadheads, iron...  2021-09-23T14:00:18Z
# 4  [IRON WILL ARCHERY, iron will broadheads, iron...  2021-09-19T17:00:05Z
# 5  [archery, mathews, pse archery, hoyt archery, ...  2021-07-12T13:30:04Z
# 6  [mathews vxr, mathews vxr 31.5, mathews vxr 28...  2020-11-15T03:26:20Z
# 7  [hoyt, hoyt archery, hoyt 2021, lighted nocks,...  2020-11-06T21:00:03Z
# 8  [hoyt, hoyt archery, hoyt 2021, lighted nocks,...  2020-11-04T03:29:38Z
#
#   viewCount likeCount favouriteCount commentCount duration definition caption
# 0       877        17           None            0    PT48S         hd   false
# 1      8221        89           None           29  PT2M38S         hd   false
# 2       724        17           None            1  PT6M50S         hd   false
# 3       709        10           None            1    PT24S         hd   false
# 4      4122        48           None            3  PT1M22S         hd   false
# 5      1157        16           None            0    PT37S         hd   false
# 6      7029        44           None            1    PT27S         hd   false
# 7       118         5           None            0    PT30S         hd   false
# 8       108         4           None            0    PT18S         hd   false

# %%
def get_comments_in_videos(youtube, video_ids):
    all_comments = []
    
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %%
comments_df = get_comments_in_videos(youtube,video_ids)
comments_df
# Out:
#       video_id                                           comments
# 0  TuIJMMTlUqU                                                 []
# 1  CwDmKZ85B14  [at 29.5" you're in the first position of the ...
# 2  YaWiiPFDL4A         [Perfect been looking for this! Thank you]
# 3  vMgFeG9YSHU  [Not much difference if any. They'll hear the ...
# 4  8yapCQvNerg  [This doesn’t prove it’s the Broadhead, easily...
# 5  f27RBDQ-qII                                                 []
# 6  Ynvrepob1QA  [Wow the rest dropped all the way down before ...
# 7  JsGGLmrDol4                                                 []
# 8  jjECrxjVLEw                                                 []

# %%
comments_df['comments'][6]
# Out:
# ['Wow the rest dropped all the way down before the arrow was halfway through. not impressed!']

# %% [markdown]
# ## Data-Preprocessing

# %%
numeric_cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[numeric_cols] = video_df[numeric_cols].apply(pd.to_numeric, errors = 'coerce', axis=1)

# %%
video_df['publishedAt'] =  video_df['publishedAt'].apply(lambda x: parser.parse(x)) 
video_df['pushblishDayName'] = video_df['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
video_df['durationSecs'] = video_df['duration'].apply(lambda x: isodate.parse_duration(x))
video_df['durationSecs'] = video_df['durationSecs'].astype('timedelta64[s]')

# %%
video_df['tagsCount'] = video_df['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df['likeRatio'] = video_df['likeCount']/ video_df['viewCount'] * 1000
video_df['commentRatio'] = video_df['commentCount']/ video_df['viewCount'] * 1000

# %%
video_df
# Out:
#       video_id         channelTitle  \
# 0  TuIJMMTlUqU  Midwest Bow & Arrow
# 1  CwDmKZ85B14  Midwest Bow & Arrow
# 2  YaWiiPFDL4A  Midwest Bow & Arrow
# 3  vMgFeG9YSHU  Midwest Bow & Arrow
# 4  8yapCQvNerg  Midwest Bow & Arrow
# 5  f27RBDQ-qII  Midwest Bow & Arrow
# 6  Ynvrepob1QA  Midwest Bow & Arrow
# 7  JsGGLmrDol4  Midwest Bow & Arrow
# 8  jjECrxjVLEw  Midwest Bow & Arrow
#
#                                                title  \
# 0                  80# Hoyt Ventum Pro 33 Speed Test
# 1  Hoyt Z1S vs PSE Omen vs 80# Ventum Pro 33 - SP...
# 2  Create Your One Stick: The Wingman Platform by...
# 3  Iron Will Broadheads - Solid vs Vented Noise Test
# 4  Iron Will Broadheads - How LOUD are the vented...
# 5         The Sound of Archery - South Forty Archers
# 6  Mathews UltraRest Integrated MX (QAD) - Slow M...
# 7  Hoyt REDWRX Carbon RX-1 Ultra - Nockturnal Lig...
# 8     Hoyt Defiant 34 - Red Nockturnal Lighted Nocks
#
#                                          description  \
# 0  check out https://www.bwanaarchery.com/\ngo fo...
# 1  Bwana Archery\nShoot off between the speed bow...
# 2  Part 2/2 will show you how to use it. \n\nLink...
# 3  Pure unscientific broadhead noise testing betw...
# 4  Pure unscientific broadhead noise testing betw...
# 5                      would you just listen to that
# 6  Mathews VXR 31.5\nMathews UltraRest Integrated...
# 7  Hoyt REDWRX Carbon RX-1 Ultra - Nockturnal Lig...
# 8  Nockturnal Lighted Nocks are awesome! \nHoyt D...
#
#                                                 tags  \
# 0  [HOYT Z1S, HOYT VENTUM PRO, 80LB BOW, 80# BOW,...
# 1  [HOYT Z1S, HOYT VENTUM PRO, 80LB BOW, 80# BOW,...
# 2  [archery country, powder ridge 3d shoot, pse e...
# 3  [IRON WILL ARCHERY, iron will broadheads, iron...
# 4  [IRON WILL ARCHERY, iron will broadheads, iron...
# 5  [archery, mathews, pse archery, hoyt archery, ...
# 6  [mathews vxr, mathews vxr 31.5, mathews vxr 28...
# 7  [hoyt, hoyt archery, hoyt 2021, lighted nocks,...
# 8  [hoyt, hoyt archery, hoyt 2021, lighted nocks,...
#
#                 publishedAt  viewCount  likeCount  favouriteCount  \
# 0 2023-01-09 14:50:12+00:00      877.0       17.0             NaN
# 1 2022-12-29 14:45:00+00:00     8221.0       89.0             NaN
# 2 2022-08-17 13:44:45+00:00      724.0       17.0             NaN
# 3 2021-09-23 14:00:18+00:00      709.0       10.0             NaN
# 4 2021-09-19 17:00:05+00:00     4122.0       48.0             NaN
# 5 2021-07-12 13:30:04+00:00     1157.0       16.0             NaN
# 6 2020-11-15 03:26:20+00:00     7029.0       44.0             NaN
# 7 2020-11-06 21:00:03+00:00      118.0        5.0             NaN
# 8 2020-11-04 03:29:38+00:00      108.0        4.0             NaN
#
#    commentCount duration definition caption pushblishDayName    durationSecs  \
# 0           0.0    PT48S         hd   false           Monday 0 days 00:00:48
# 1          29.0  PT2M38S         hd   false         Thursday 0 days 00:02:38
# 2           1.0  PT6M50S         hd   false        Wednesday 0 days 00:06:50
# 3           1.0    PT24S         hd   false         Thursday 0 days 00:00:24
# 4           3.0  PT1M22S         hd   false           Sunday 0 days 00:01:22
# 5           0.0    PT37S         hd   false           Monday 0 days 00:00:37
# 6           1.0    PT27S         hd   false           Sunday 0 days 00:00:27
# 7           0.0    PT30S         hd   false           Friday 0 days 00:00:30
# 8           0.0    PT18S         hd   false        Wednesday 0 days 00:00:18
#
#    tagsCount
# 0         34
# 1         34
# 2         27
# 3         27
# 4         27
# 5         35
# 6         29
# 7         31
# 8         30

# %% [markdown]
# # EDA

# %% [markdown]
# ## Best Performing Videos

# %%
ax = sns.barplot(x='title', y='viewCount', data=video_df.sort_values('viewCount', ascending=False)[0:9])
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.0f}'.format(x/1000) + 'K'))
plot = ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)

# %% [markdown]
# ## View distribution per video

# %%
sns.violinplot(x=video_df['channelTitle'], y=video_df['viewCount'])
# Out:
# <Axes: xlabel='channelTitle', ylabel='viewCount'>

# %% [markdown]
# # Comment vs Like Count

# %%
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "commentCount", y = "viewCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "likeCount", y = "viewCount", ax=ax[1])

#Ratio
fig, ax =plt.subplots(1,2)
sns.scatterplot(data = video_df, x = "commentRatio", y = "viewCount", ax=ax[0])
sns.scatterplot(data = video_df, x = "likeRatio", y = "viewCount", ax=ax[1])
# Out:
# <Axes: xlabel='likeRatio', ylabel='viewCount'>

# %% [markdown]
# ## Average Video Duration

# %%
sns.histplot(data=video_df, x="durationSecs", bins=30)
# Out:
# <Axes: xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# ## Word Cloud

# %% [markdown]
# Which words appear most often in the videos?

# %%
stop_words = set(stopwords.words('english'))
video_df['title_no_stopwords'] = video_df['title'].apply(lambda x: [item for item in str(x).split() if item not in stop_words])

all_words = list([a for b in video_df['title_no_stopwords'].tolist() for a in b])
all_words_str = ' '.join(all_words)

# %%
def plot_cloud(wordcloud):
    plt.figure(figsize=(30, 20))
    plt.imshow(wordcloud) 
    plt.axis("off");

wordcloud = WordCloud(width = 2000, height = 1000, random_state=1, background_color='black', 
                      colormap='viridis', collocations=False).generate(all_words_str)
plot_cloud(wordcloud)

# %% [markdown]
# ## Number of tags vs views

# %%
sns.scatterplot(data = video_df, x = "tagsCount", y = "viewCount")
# Out:
# <Axes: xlabel='tagsCount', ylabel='viewCount'>
